# %%
# loc and iloc imp
# loc looks at the index 
# iloc gives it form the

# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df = df.sample(frac = 1) # 1 = 100% sample rows 
df.head()
# Out:
#      PassengerId  Survived  Pclass  \
# 841          842         0       2
# 180          181         0       3
# 416          417         1       2
# 828          829         1       3
# 390          391         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 841                         Mudd, Mr. Thomas Charles    male  16.0      0
# 180                     Sage, Miss. Constance Gladys  female   NaN      8
# 416  Drew, Mrs. James Vivian (Lulu Thorne Christian)  female  34.0      1
# 828                     McCormack, Mr. Thomas Joseph    male   NaN      0
# 390                       Carter, Mr. William Ernest    male  36.0      1
#
#      Parch       Ticket    Fare    Cabin Embarked
# 841      0  S.O./P.P. 3   10.50      NaN        S
# 180      2     CA. 2343   69.55      NaN        S
# 416      1        28220   32.50      NaN        S
# 828      0       367228    7.75      NaN        Q
# 390      2       113760  120.00  B96 B98        S

# %%
df.iloc[4]
# Out:
# PassengerId                           391
# Survived                                1
# Pclass                                  1
# Name           Carter, Mr. William Ernest
# Sex                                  male
# Age                                  36.0
# SibSp                                   1
# Parch                                   2
# Ticket                             113760
# Fare                                120.0
# Cabin                             B96 B98
# Embarked                                S
# Name: 390, dtype: object

# %%
df.loc[5]
# Out:
# PassengerId                   6
# Survived                      0
# Pclass                        3
# Name           Moran, Mr. James
# Sex                        male
# Age                         NaN
# SibSp                         0
# Parch                         0
# Ticket                   330877
# Fare                     8.4583
# Cabin                       NaN
# Embarked                      Q
# Name: 5, dtype: object

# %%
df.loc[4,'Sex']
# df.iloc[[8,9],4]
# Out:
# 'male'

# %%
df.loc[788]
# Out:
# PassengerId                           789
# Survived                                1
# Pclass                                  3
# Name           Dean, Master. Bertram Vere
# Sex                                  male
# Age                                   1.0
# SibSp                                   1
# Parch                                   2
# Ticket                          C.A. 2315
# Fare                               20.575
# Cabin                                 NaN
# Embarked                                S
# Name: 788, dtype: object

# %%
#iloc part 2
female_df = df[df.Sex =='male']
female_df.head()
# Out:
#      PassengerId  Survived  Pclass                               Name   Sex  \
# 444          445         1       3  Johannesen-Bratthammer, Mr. Bernt  male
# 794          795         0       3              Dantcheff, Mr. Ristiu  male
# 743          744         0       3                  McNamee, Mr. Neal  male
# 234          235         0       2  Leyson, Mr. Robert William Norman  male
# 602          603         0       1          Harrington, Mr. Charles H  male
#
#       Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 444   NaN      0      0       65306   8.1125   NaN        S
# 794  25.0      0      0      349203   7.8958   NaN        S
# 743  24.0      1      0      376566  16.1000   NaN        S
# 234  24.0      0      0  C.A. 29566  10.5000   NaN        S
# 602   NaN      0      0      113796  42.4000   NaN        S

# %%
female_df.loc[:4]['Survived']
# Out:
# 444    1
# 794    0
# 743    0
# 234    0
# 602    0
# 746    0
# 505    0
# 482    0
# 294    0
# 196    0
# 884    0
# 138    0
# 170    0
# 749    0
# 465    0
# 5      0
# 583    0
# 733    0
# 320    0
# 101    0
# 850    0
# 812    0
# 514    0
# 735    0
# 76     0
# 125    1
# 363    0
# 666    0
# 659    0
# 782    0
# 683    0
# 418    0
# 867    0
# 204    1
# 324    0
# 488    0
# 705    0
# 360    0
# 262    0
# 694    0
# 287    0
# 764    0
# 817    0
# 336    0
# 721    0
# 740    1
# 95     0
# 54     0
# 201    0
# 582    0
# 220    1
# 4      0
# Name: Survived, dtype: int64

# %%
female_df.iloc[:4]
# Out:
#      PassengerId  Survived  Pclass                               Name   Sex  \
# 444          445         1       3  Johannesen-Bratthammer, Mr. Bernt  male
# 794          795         0       3              Dantcheff, Mr. Ristiu  male
# 743          744         0       3                  McNamee, Mr. Neal  male
# 234          235         0       2  Leyson, Mr. Robert William Norman  male
#
#       Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 444   NaN      0      0       65306   8.1125   NaN        S
# 794  25.0      0      0      349203   7.8958   NaN        S
# 743  24.0      1      0      376566  16.1000   NaN        S
# 234  24.0      0      0  C.A. 29566  10.5000   NaN        S

# %%
female_df.iloc[:4][['Survived', 'Name', 'Pclass']]
# Out:
#      Survived                               Name  Pclass
# 444         1  Johannesen-Bratthammer, Mr. Bernt       3
# 794         0              Dantcheff, Mr. Ristiu       3
# 743         0                  McNamee, Mr. Neal       3
# 234         0  Leyson, Mr. Robert William Norman       2

# %%
female_df.loc[female_df['Pclass']==3,['Survived','Name']]
# Out:
#      Survived                               Name
# 444         1  Johannesen-Bratthammer, Mr. Bernt
# 794         0              Dantcheff, Mr. Ristiu
# 743         0                  McNamee, Mr. Neal
# 746         0        Abbott, Mr. Rossmore Edward
# 482         0           Rouse, Mr. Richard Henry
# ..        ...                                ...
# 73          0        Chronopoulos, Mr. Apostolos
# 776         0                   Tobin, Mr. Roger
# 400         1                 Niskanen, Mr. Juha
# 261         1  Asplund, Master. Edvin Rojj Felix
# 725         0                Oreskovic, Mr. Luka
#
# [347 rows x 2 columns]
